# %% [markdown]
# <a href="https://colab.research.google.com/github/abdullah-621/pandas/blob/main/session_18_dataframe_methods.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
marks = pd.DataFrame([
    [100,70,80],
    [87,67,85],
    [98,78,83],
    [10,79,81],
    [78,71,80],
], columns = ['iq','marks','package'])

# %%
marks

# %%
# value_counts()
marks.value_counts()

# %%
ipl = pd.read_csv('ipl-matches.csv')
ipl.head(2)

# %%
ipl[~ipl['MatchNumber'].str.isdigit()]['Player_of_Match'].value_counts()

# %%
ipl['TossDecision'].value_counts().plot(kind='pie')

# %%
# How many matches each team has played

mask1 = ipl['Team1'].unique()
mask2 = ipl['Team2'].unique()

All_Team = np.unique(np.concatenate([mask1, mask2]))
All_Team = list(All_Team)

Matches = {
    "Team" : [],
    "Times" : []
}

for team in All_Team:
  mask = (ipl['Team1'] == team) | (ipl['Team2'] == team)
  Matches['Team'].append(team)
  Matches['Times'].append(mask.sum())

Matches = pd.DataFrame(Matches)
Matches.sort_values(by='Times', ascending=False)

# %%
(ipl['Team1'].value_counts() + ipl['Team2'].value_counts()).sort_values(ascending=False)

# %%
movies = pd.read_csv('movies.csv')
movies.head(3)

# %%
movies.sort_values(by='title_x', ascending = False)

# %%
students = pd.DataFrame(
    {
        'name':['nitish','ankit','rupesh',np.nan,'mrityunjay',np.nan,'rishabh',np.nan,'aditya',np.nan],
        'college':['bit','iit','vit',np.nan,np.nan,'vlsi','ssit',np.nan,np.nan,'git'],
        'branch':['eee','it','cse',np.nan,'me','ce','civ','cse','bio',np.nan],
        'cgpa':[6.66,8.25,6.41,np.nan,5.6,9.0,7.4,10,7.4,np.nan],
        'package':[4,5,6,np.nan,6,7,8,9,np.nan,np.nan]

    }
)

students

# %%
students.sort_values('name', na_position='first')

# %%
movies.sort_values(by=['year_of_release','title_x'], ascending=[True, False])

# %%
# rank
batesman = pd.read_csv('/content/batsman_runs_ipl.csv')
batesman.head()

# %%
batesman['rank'] = batesman['batsman_run'].rank(ascending=False)
batesman.sort_values('rank')

# %%
# set_index (Datafream)
batesman.set_index('batter', inplace = True)

# %%
# reset_index (series and Datafream)

batesman.reset_index(inplace=True)

# %%
batesman

# %%
batesman.set_index('batter', inplace=True)

# %%
# how to replace without lossing the columns
batesman.reset_index().set_index('rank')

# %%
movies.set_index('title_x', inplace=True)

# %%
movies.rename(columns={'imdb_id':'imdb', 'poster_path':'link'}, inplace=True)

# %%
movies

# %%
movies.rename(index= {'Uri: The Surgical Strike':'Uri'})

# %%
ipl['Season'].unique().size

# %%
# nuinque (this is not count the missing values)

ipl['Season'].nunique()

# %%
# isnull
students['name'].isnull()

# %%
# notnull
students['name'].notnull()

# %%
students['name'].hasnans

# %%
students.isnull()

# %%
students

# %%
# dropna
students.dropna()

# %%
students.dropna(how='all')

# %%
students.dropna(subset=['name'])

# %%
students.dropna(subset=['name','college'])

# %%
# drop_duplicate
marks.duplicated()

# %%
ipl.head()

# %%
ipl['all_playres'] = ipl['Team1Players'] + ipl['Team2Players']
type(ipl['all_playres'])

# %%
ipl

# %%
def did_kohli_play(player_list):
  return 'V Kohli' in player_list

# %%
ipl[ipl['all_playres'].apply(did_kohli_play) & ( ipl['City'] == 'Delhi')].drop_duplicates(subset=['City'],keep='first')

# ipl[(ipl['did_kohli_play'] == True) &( ipl['City'] == 'Delhi')]

# %%
# drop
temp = pd.Series([1,2,3,4,5,6,7])
temp.drop([0,4])

# %%
students.drop(columns= ['cgpa']) # columns

# %%
# drop row
students.set_index('name').drop(index=['nitish',np.nan])

# %%
students.drop(index=[0,1])

# %%
# apply
temp = pd.Series([1,2,3,4,5,6,7])
temp.apply(lambda x: x * 8)

# %%
def sigmoid(value):
  return 1 / (1 + np.exp(-value))

# %%
temp.apply(sigmoid)

# %%
points_df = pd.DataFrame(
    {
        '1st point':[(3,4),(-6,5),(0,0),(-10,1),(4,5)],
        '2nd point':[(-3,4),(0,0),(2,2),(10,10),(1,1)]
    }
)

points_df

# %%
def euclidean(row):
  pt_A = row['1st point']
  pt_B = row['2nd point']

  return ((pt_A[0] - pt_B[0])**2 + (pt_A[1] - pt_B[1])**2)**0.5

# %%
points_df['Distance'] = points_df.apply(euclidean, axis=1)
points_df
